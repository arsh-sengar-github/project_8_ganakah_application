# %% [markdown]
# # Flag Invoice
#
# **Objective:** Flag an *Invoice* for manual approval based on cost, and/or delay to reduce risk, improve efficiency, and prioritize human intervention.

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
conn = sqlite3.connect("/Users/arshs/projects/project_8/data/inventory.db")
tables = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table';", conn)

# %%
tables
# Out:
#               name
# 0        purchases
# 1  purchase_prices
# 2   vendor_invoice
# 3  begin_inventory
# 4    end_inventory

# %%
for table in tables["name"]:
    print(f"Table: {table}")
    df = pd.read_sql_query(f"SELECT * FROM {table} LIMIT 5;", conn)
    display(df)
# Out:
# Table: purchases
#            InventoryId  Store  Brand                   Description   Size  \
# 0    69_MOUNTMEND_8412     69   8412     Tequila Ocho Plata Fresno  750mL
# 1     30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 2    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 3  1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 4    76_DONCASTER_2034     76   2034     Glendalough Double Barrel  750mL
#
#    VendorNumber                   VendorName  PONumber      PODate  \
# 0           105  ALTAMAR BRANDS LLC               8124  2023-12-21
# 1          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 2          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 3          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 4           388  ATLANTIC IMPORTING COMPANY       8169  2023-12-24
#
#   ReceivingDate InvoiceDate     PayDate  PurchasePrice  Quantity  Dollars  \
# ...

# %%
pd.read_sql_query("""
SELECT
p.PONumber,
COUNT(DISTINCT p.Brand) AS TotalBrands,
SUM(p.Quantity) AS TotalQuantity,
SUM(p.Dollars) AS TotalDollars,
AVG(julianday(p.ReceivingDate) - julianday(p.PODate)) AS AverageReceivingDelay
FROM purchases p
GROUP BY p.PONumber
""", conn)
# Out:
#       PONumber  TotalBrands  TotalQuantity  TotalDollars  \
# 0         8106           81          10100     137483.78
# 1         8107            2             24        348.72
# 2         8108          165           8466      60281.13
# 3         8109           23           2246      14298.09
# 4         8110          183           8086      56493.23
# ...        ...          ...            ...           ...
# 5538     13657            3            253       3844.39
# 5539     13658          111          14115     102949.38
# 5540     13659           13            338       2492.20
# 5541     13660           12            195       2599.66
# 5542     13661          110          24747     149007.56
#
#       AverageReceivingDelay
# 0                 12.614130
# 1                 12.500000
# 2                 12.632479
# 3                 12.626866
# 4                 12.695271
# ...                     ...
# 5538               4.870968
# 5539               5.016349
# ...

# %%
pd.read_sql_query("""
SELECT
vi.PONumber,
vi.Quantity AS InvoiceQuantity,
vi.Dollars AS InvoiceDollars,
vi.Freight,
(julianday(vi.InvoiceDate) - julianday(vi.PODate)) AS InvoicingDelay,
(julianday(vi.PayDate) - julianday(vi.InvoiceDate)) AS PayingDelay
FROM vendor_invoice vi
""", conn)
# Out:
#       PONumber  InvoiceQuantity  InvoiceDollars  Freight  InvoicingDelay  \
# 0         8124                6          214.26     3.47            14.0
# 1         8137               15          140.55     8.57            16.0
# 2         8169                5          106.60     4.61            16.0
# 3         8106            10100       137483.78  2935.20            23.0
# 4         8170             1935        15527.25   429.20            14.0
# ...        ...              ...             ...      ...             ...
# 5538     13626               90         1563.00     8.60            16.0
# 5539     13661             4617        37300.48   186.50            18.0
# 5540     13643             9848       202815.78   932.95            11.0
# 5541     13602            24747       149007.56   819.54            14.0
# 5542     13574              437         3608.11    16.60            18.0
#
#       PayingDelay
# 0            43.0
# 1            45.0
# 2            38.0
# ...

# %%
df = pd.read_sql_query("""
WITH purchase_agg AS (
SELECT
p.PONumber,
COUNT(DISTINCT p.Brand) AS TotalBrands,
SUM(p.Quantity) AS TotalQuantity,
SUM(p.Dollars) AS TotalDollars,
AVG(julianday(p.ReceivingDate) - julianday(p.PODate)) AS AverageReceivingDelay
FROM purchases p
GROUP BY p.PONumber
)
SELECT
vi.PONumber,
vi.Quantity AS InvoiceQuantity,
vi.Dollars AS InvoiceDollars,
vi.Freight,
(julianday(vi.InvoiceDate) - julianday(vi.PODate)) AS InvoicingDelay,
(julianday(vi.PayDate) - julianday(vi.InvoiceDate)) AS PayingDelay,
pa.TotalBrands,
pa.TotalQuantity,
pa.TotalDollars,
pa.AverageReceivingDelay
FROM vendor_invoice vi
LEFT JOIN purchase_agg pa
ON vi.PONumber = pa.PONumber
""", conn)

# %%
df.isnull().sum()
# Out:
# PONumber                 0
# InvoiceQuantity          0
# InvoiceDollars           0
# Freight                  0
# InvoicingDelay           0
# PayingDelay              0
# TotalBrands              0
# TotalQuantity            0
# TotalDollars             0
# AverageReceivingDelay    0
# dtype: int64

# %%
df.dtypes
# Out:
# PONumber                   int64
# InvoiceQuantity            int64
# InvoiceDollars           float64
# Freight                  float64
# InvoicingDelay           float64
# PayingDelay              float64
# TotalBrands                int64
# TotalQuantity              int64
# TotalDollars             float64
# AverageReceivingDelay    float64
# dtype: object

# %%
def label_risks(row):
    # Consider large discrepancies between invoice and purchase order as a risk factor.
    if (abs(row["InvoiceDollars"] - row["TotalDollars"]) > 5):
        return 1
    # Consider delays as a risk factor.
    if row["AverageReceivingDelay"] > 10:
        return 1
    return 0

# %%
df["FlagInvoice"] = df.apply(label_risks, axis=1)

# %%
df["FlagInvoice"].value_counts()
# Out:
# FlagInvoice
# 0    3693
# 1    1850
# Name: count, dtype: int64

# %%
df["FlagInvoice"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='FlagInvoice'>

# %%
df.corr()
# Out:
#                        PONumber  InvoiceQuantity  InvoiceDollars   Freight  \
# PONumber               1.000000         0.049230        0.058917  0.043617
# InvoiceQuantity        0.049230         1.000000        0.963831  0.946550
# InvoiceDollars         0.058917         0.963831        1.000000  0.985141
# Freight                0.043617         0.946550        0.985141  1.000000
# InvoicingDelay        -0.002234         0.000526        0.001610  0.003265
# PayingDelay            0.012558         0.022284        0.025661  0.025513
# TotalBrands            0.013423         0.566394        0.536952  0.536381
# TotalQuantity          0.049442         0.706117        0.667666  0.656616
# TotalDollars           0.059221         0.668171        0.679537  0.670768
# AverageReceivingDelay -0.042362         0.000519        0.004694  0.015645
# FlagInvoice            0.564946         0.032783        0.037994  0.037759
#
#                        InvoicingDelay  PayingDelay  TotalBrands  \
# ...

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(df.iloc[:,1:-1].corr(), annot=True)
plt.show()

# %%
flagged = df[df["FlagInvoice"] == 1]
not_flagged = df[df["FlagInvoice"] == 0]

# %%
significant_features = []
non_significant_features = []
results = []

# %%
metrics = ["InvoiceQuantity", "InvoiceDollars", "Freight", "InvoicingDelay", "PayingDelay", "TotalBrands", "TotalQuantity", "TotalDollars", "AverageReceivingDelay"]

# %%
from scipy.stats import ttest_ind

# %%
for metric in metrics:
    flagged_mean = flagged[metric].mean()
    not_flagged_mean = not_flagged[metric].mean()
    t_state, p_value = ttest_ind(flagged[metric].dropna(), not_flagged[metric].dropna(), equal_var=False)
    if p_value < 0.05:
        significant_features.append(metric)
        results.append({
            "metric": metric,
            "flagged_mean": flagged_mean.round(2),
            "not_flagged_mean": not_flagged_mean.round(2),
            "p_value": p_value.round(4)
        })
    else:
        non_significant_features.append(metric)

# %%
significant_features
# Out:
# ['InvoiceQuantity',
#  'InvoiceDollars',
#  'Freight',
#  'InvoicingDelay',
#  'TotalQuantity',
#  'TotalDollars',
#  'AverageReceivingDelay']

# %%
non_significant_features
# Out:
# ['PayingDelay', 'TotalBrands']

# %%
results
# Out:
# [{'metric': 'InvoiceQuantity',
#   'flagged_mean': np.float64(6728.28),
#   'not_flagged_mean': np.float64(5723.55),
#   'p_value': np.float64(0.0213)},
#  {'metric': 'InvoiceDollars',
#   'flagged_mean': np.float64(65600.61),
#   'not_flagged_mean': np.float64(54302.64),
#   'p_value': np.float64(0.008)},
#  {'metric': 'Freight',
#   'flagged_mean': np.float64(334.02),
#   'not_flagged_mean': np.float64(276.89),
#   'p_value': np.float64(0.0082)},
#  {'metric': 'InvoicingDelay',
#   'flagged_mean': np.float64(17.23),
#   'not_flagged_mean': np.float64(16.02),
#   'p_value': np.float64(0.0)},
#  {'metric': 'TotalQuantity',
#   'flagged_mean': np.float64(6728.28),
#   'not_flagged_mean': np.float64(5723.55),
#   'p_value': np.float64(0.0213)},
#  {'metric': 'TotalDollars',
#   'flagged_mean': np.float64(65600.61),
#   'not_flagged_mean': np.float64(54302.64),
#   'p_value': np.float64(0.008)},
#  {'metric': 'AverageReceivingDelay',
#   'flagged_mean': np.float64(8.47),
# ...

# %%
x = df[["InvoiceQuantity", "InvoiceDollars", "Freight", "InvoicingDelay", "TotalBrands", "TotalQuantity", "TotalDollars"]]
y = df["FlagInvoice"]

# %%
x.describe().round()
# Out:
#        InvoiceQuantity  InvoiceDollars  Freight  InvoicingDelay  TotalBrands  \
# count           5543.0          5543.0   5543.0          5543.0       5543.0
# mean            6059.0         58073.0    296.0            16.0         41.0
# std            14453.0        140234.0    714.0             3.0         77.0
# min                1.0             4.0      0.0             9.0          1.0
# 25%               83.0           968.0      5.0            14.0          3.0
# 50%              423.0          4765.0     25.0            16.0          7.0
# 75%             5100.0         44587.0    230.0            19.0         46.0
# max           141660.0       1660436.0   8468.0            23.0        807.0
#
#        TotalQuantity  TotalDollars
# count         5543.0        5543.0
# mean          6059.0       58073.0
# std          14453.0      140234.0
# min              1.0           4.0
# 25%             83.0         968.0
# 50%            423.0        4765.0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
model_1 = LogisticRegression(random_state=42)
model_1.fit(x_train_scaled, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
model_2 = DecisionTreeClassifier(random_state=42)
model_2.fit(x_train_scaled, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
model_3 = RandomForestClassifier(random_state=42)
model_3.fit(x_train_scaled, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
def evaluate_model(model, x_test, y_test, model_name):
    preds = model.predict(x_test)
    accuracy = accuracy_score(y_test, preds)
    report = classification_report(y_test, preds)
    print(f"Model: {model_name}")
    print(f"Accuracy: {accuracy:.2f}")
    print("Classification Report:")
    print(report)

# %%
evaluate_model(model_1, x_test_scaled, y_test, "Logistic Regression")
# Out:
# Model: Logistic Regression
# Accuracy: 0.66
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.66      0.98      0.79       725
#            1       0.56      0.06      0.11       384
#
#     accuracy                           0.66      1109
#    macro avg       0.61      0.52      0.45      1109
# weighted avg       0.63      0.66      0.55      1109

# %%
evaluate_model(model_2, x_test_scaled, y_test, "Decision Tree Classifier")
# Out:
# Model: Decision Tree Classifier
# Accuracy: 0.81
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.86      0.86       725
#            1       0.73      0.71      0.72       384
#
#     accuracy                           0.81      1109
#    macro avg       0.79      0.79      0.79      1109
# weighted avg       0.81      0.81      0.81      1109

# %%
evaluate_model(model_3, x_test_scaled, y_test, "Random Forest Classifier")
# Out:
# Model: Random Forest Classifier
# Accuracy: 0.87
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.91       725
#            1       0.93      0.68      0.79       384
#
#     accuracy                           0.87      1109
#    macro avg       0.89      0.83      0.85      1109
# weighted avg       0.88      0.87      0.87      1109

# %%
feature_importance = pd.DataFrame({
    "feature": x_train.columns,
    "importance": model_3.feature_importances_
}).sort_values(by="importance", ascending=False)

# %%
feature_importance
# Out:
#            feature  importance
# 6     TotalDollars    0.222132
# 5    TotalQuantity    0.173431
# 1   InvoiceDollars    0.158210
# 2          Freight    0.150645
# 0  InvoiceQuantity    0.135219
# 4      TotalBrands    0.082845
# 3   InvoicingDelay    0.077519

# %%
x = df[["InvoiceQuantity", "InvoiceDollars", "Freight", "TotalQuantity", "TotalDollars"]]
y = df["FlagInvoice"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
model_3 = RandomForestClassifier(random_state=42)
model_3.fit(x_train_scaled, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
evaluate_model(model_3, x_test_scaled, y_test, "Random Forest Classifier")
# Out:
# Model: Random Forest Classifier
# Accuracy: 0.88
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92       725
#            1       0.94      0.72      0.81       384
#
#     accuracy                           0.88      1109
#    macro avg       0.90      0.84      0.86      1109
# weighted avg       0.89      0.88      0.88      1109

# %%
from sklearn.metrics import make_scorer, f1_score
from sklearn.model_selection import GridSearchCV

# %%
rf = RandomForestClassifier(n_jobs=-1, random_state=42)
param_grid = {
    "n_estimators": [100, 200, 300],
    "criterion": ["gini", "entropy", "log_loss"],
    "max_depth": [None, 4, 6],
    "min_samples_split": [2, 4, 6],
    "min_samples_leaf": [1, 3, 5]
}
scorer = make_scorer(f1_score)
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, scoring=scorer, cv=5, verbose=2, n_jobs=-1)
grid_search.fit(x_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(n_jobs=-1, random_state=42),
#              n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [None, 4, 6],
#                          'min_samples_leaf': [1, 3, 5],
#                          'min_samples_split': [2, 4, 6],
#                          'n_estimators': [100, 200, 300]},
#              scoring=make_scorer(f1_score, response_method='predict'),
#              verbose=2)

# %%
evaluate_model(grid_search, x_test_scaled, y_test, "Random Forest Classifier")
# Out:
# Model: Random Forest Classifier
# Accuracy: 0.89
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92       725
#            1       0.95      0.72      0.82       384
#
#     accuracy                           0.89      1109
#    macro avg       0.91      0.85      0.87      1109
# weighted avg       0.90      0.89      0.89      1109

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(model_3.predict(x_test_scaled), y_test)
# Out:
# array([[706, 109],
#        [ 19, 275]])

# %%
confusion_matrix(grid_search.predict(x_test_scaled), y_test)
# Out:
# array([[712, 109],
#        [ 13, 275]])

# %%
grid_search.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 6,
#  'n_estimators': 300}
